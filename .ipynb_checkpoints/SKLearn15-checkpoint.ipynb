# %% [markdown]
# # Classification Task dengan Decision Tree

# %% [markdown]
# Struktur unutk membantu mengambil keputusan dengan metode seperti pohon dan kemungkinan konsekuensinya, termasuk hasil.

# %% [markdown]
# # Konsep Dasar

# %% [markdown]
# **Terminology : root node, internal node, leaf node**

# %% [markdown]
# ![decision_tree_example.png](attachment:decision_tree_example.png)

# %% [markdown]
# Algoritma Decision Tree lainnya :
# - ID3
# - C4.5
# - C5.0

# %% [markdown]
# **Gini Impurity**

# %% [markdown]
# ![gini_example.png](attachment:gini_example.png)

# %% [markdown]
# Ruas Kiri :
#
# $ G = 1 - \displaystyle\sum_{i}^n P^2_i $
#
# $ G = 1 - (biru)^2 $
#
# $ G = 1 -(\frac{4}{4})^2 = 0 $
#
#
# Ruas Kanan :
#
# $ G = 1 - \displaystyle\sum_{i}^n P^2_i $
#
# $ G = 1 - P(biru)^2 + P(hijau)^2) $
#
# $ G = 1 - ((\frac{1}{6})^2 + (\frac{5}{6})^2) = 0.278 $
#
# Average Gini Impurity :
#
# $ G = \frac{4}{4+6} \times 0 + \frac{6}{4+6} \times 0.278 $
#
# $ G = 0.1668 $

# %% [markdown]
# # Information Gain

# %% [markdown]
# ![information_gain.png](attachment:information_gain.png)

# %% [markdown]
# # Membangun Decision Tree

# %% [markdown]
# ![build_decision_tree.png](attachment:build_decision_tree.png)

# %% [markdown]
# $ G = 1 - (P(apple)^2 + P(grape)^2 + P(lemon)^2) $
#
# $ G = 1 - ((\frac25)^2 + (\frac25)^2 + (\frac15)^2) $
#
# $ G = 0.63 $

# %% [markdown]
# # Dataset

# %%
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True)

print(f'Dimensi Feature: {X.shape}')
print(f'Class : {set(y)}')
# Out:
# Dimensi Feature: (150, 4)
# Class : {0, 1, 2}

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                              y,
                                              test_size=0.3,
                                              random_state=0)

# %% [markdown]
# # Classification dengan `DecisionTreeClassifer`

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=4)

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %% [markdown]
# # Visualisasi Model

# %%
import matplotlib.pyplot as plt
from sklearn import tree

plt.rcParams['figure.dpi'] = 85
plt.subplots(figsize=(10, 10))
tree.plot_tree(model, fontsize=10)
plt.show()

# %% [markdown]
# # Evaluasi Model

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
